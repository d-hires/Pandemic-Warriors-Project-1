# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as pyplt
from matplotlib.ticker import MultipleLocator, ScalarFormatter
import scipy.stats as st
import numpy as np
import random

# %%
file='cvs_output.csv'

file_one = pd.read_csv(file)
file_one
# Out:
#       Unnamed: 0                        indicator              group  \
# 0              0  Symptoms of Depressive Disorder  National Estimate
# 1              1  Symptoms of Depressive Disorder             By Age
# 2              2  Symptoms of Depressive Disorder             By Age
# 3              3  Symptoms of Depressive Disorder             By Age
# 4              4  Symptoms of Depressive Disorder             By Age
# ...          ...                              ...                ...
# 1995        1995     Symptoms of Anxiety Disorder           By State
# 1996        1996     Symptoms of Anxiety Disorder           By State
# 1997        1997     Symptoms of Anxiety Disorder           By State
# 1998        1998     Symptoms of Anxiety Disorder           By State
# 1999        1999     Symptoms of Anxiety Disorder           By State
#
#               state       subgroup  week       week_label  value  lowci  \
# 0     United States  United States     1   Apr 23 - May 5   23.5   22.7
# 1     United States  18 - 29 years     1   Apr 23 - May 5   32.7   30.2
# 2     United States  30 - 39 years     1   Apr 23 - May 5   25.7   24.1
# 3     United States  40 - 49 years     1   Apr 23 - May 5   24.8   23.3
# 4     United States  50 - 59 years     1   Apr 23 - May 5   23.2   21.5
# ...             ...            ...   ...              ...    ...    ...
# 1995         Kansas         Kansas    10  July 2 - July 7   32.3   28.2
# 1996       Kentucky       Kentucky    10  July 2 - July 7   36.3   31.2
# 1997      Louisiana      Louisiana    10  July 2 - July 7   38.6   34.2
# 1998          Maine          Maine    10  July 2 - July 7   32.8   29.0
# 1999       Maryland       Maryland    10  July 2 - July 7   32.2   27.9
#
#       highci confidence_interval quartile_range
# 0       24.3         22.7 - 24.3            NaN
# 1       35.2         30.2 - 35.2            NaN
# 2       27.3         24.1 - 27.3            NaN
# 3       26.2         23.3 - 26.2            NaN
# 4       25.0         21.5 - 25.0            NaN
# ...      ...                 ...            ...
# 1995    36.6         28.2 - 36.6      31.4-32.9
# 1996    41.6         31.2 - 41.6      35.4-40.6
# 1997    43.1         34.2 - 43.1      35.4-40.6
# 1998    36.7         29.0 - 36.7      31.4-32.9
# 1999    36.7         27.9 - 36.7      31.4-32.9
#
# [2000 rows x 12 columns]

# %%
kansas_df = file_one.loc[file_one["state"] == "Kansas", :]
kansas_df['indicator'].value_counts()
kansas_df

missouri_df=file_one.loc[file_one['state']=='Missouri']
missouri_df

ks_mo=pd.merge(kansas_df,missouri_df, how='outer')
ks_mo

cleaned_KsMo=ks_mo[['indicator','state','week','value']]
cleaned_KsMo

cleaned=cleaned_KsMo.groupby(['week','indicator'])
cleaned.count().head(10)

state_mean=cleaned['value'].mean()
final=pd.DataFrame({'KS & MO Average(%)':state_mean})
final.head()
# Out:
#                                                          KS & MO Average(%)
# week indicator
# 1    Symptoms of Anxiety Disorder                                     28.40
#      Symptoms of Anxiety Disorder or Depressive Diso...               33.85
#      Symptoms of Depressive Disorder                                  21.55
# 2    Symptoms of Anxiety Disorder                                     31.45
#      Symptoms of Anxiety Disorder or Depressive Diso...               34.65

# %%
#chart for kansas 
new_name_df= file_one[["indicator", "state", "week","value"]].copy()
new_name_df
# Out:
#                             indicator          state  week  value
# 0     Symptoms of Depressive Disorder  United States     1   23.5
# 1     Symptoms of Depressive Disorder  United States     1   32.7
# 2     Symptoms of Depressive Disorder  United States     1   25.7
# 3     Symptoms of Depressive Disorder  United States     1   24.8
# 4     Symptoms of Depressive Disorder  United States     1   23.2
# ...                               ...            ...   ...    ...
# 1995     Symptoms of Anxiety Disorder         Kansas    10   32.3
# 1996     Symptoms of Anxiety Disorder       Kentucky    10   36.3
# 1997     Symptoms of Anxiety Disorder      Louisiana    10   38.6
# 1998     Symptoms of Anxiety Disorder          Maine    10   32.8
# 1999     Symptoms of Anxiety Disorder       Maryland    10   32.2
#
# [2000 rows x 4 columns]

# %%
#kansas_df.dtypes
kansas_df["week"]
ks_wks= kansas_df.groupby("indicator")["week"].count()
ks_wks
# Out:
# indicator
# Symptoms of Anxiety Disorder                           10
# Symptoms of Anxiety Disorder or Depressive Disorder     9
# Symptoms of Depressive Disorder                        10
# Name: week, dtype: int64

# %%
#chart for Kansas %'s' after ten weeks
ks_wks= kansas_df.groupby("indicator")["value"].mean()

kansas_df.groupby("indicator")["value"].mean()
ks_wks = kansas_df.groupby("indicator")["value"].mean()
ks_wks

ks_wks.plot(kind="barh",width = (.45),figsize=(10, 5), color=["powderblue","steelblue","cornflowerblue"], edgeColor=('black'), linestyle='-')

# %%
#chart for mo
Mo_df = new_name_df.loc[(new_name_df["state"]=='Missouri')]
#kansas_df[['indicator', 'week']].value_counts()
Mo_df
# Out:
#                                               indicator     state  week  value
# 44                      Symptoms of Depressive Disorder  Missouri     1   21.0
# 114                        Symptoms of Anxiety Disorder  Missouri     1   30.4
# 184   Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     1   35.2
# 254                     Symptoms of Depressive Disorder  Missouri     2   24.1
# 324                        Symptoms of Anxiety Disorder  Missouri     2   37.8
# 394   Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     2   41.3
# 464                     Symptoms of Depressive Disorder  Missouri     3   24.3
# 534                        Symptoms of Anxiety Disorder  Missouri     3   30.4
# 604   Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     3   35.4
# 674                     Symptoms of Depressive Disorder  Missouri     4   24.3
# 744                        Symptoms of Anxiety Disorder  Missouri     4   29.0
# 814   Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     4   32.9
# 884                     Symptoms of Depressive Disorder  Missouri     5   24.5
# 954                        Symptoms of Anxiety Disorder  Missouri     5   30.1
# 1024  Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     5   33.7
# 1094                    Symptoms of Depressive Disorder  Missouri     6   23.1
# 1164                       Symptoms of Anxiety Disorder  Missouri     6   23.2
# 1234  Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     6   29.5
# 1304                    Symptoms of Depressive Disorder  Missouri     7   26.1
# 1374                       Symptoms of Anxiety Disorder  Missouri     7   33.3
# 1444  Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     7   36.5
# 1514                    Symptoms of Depressive Disorder  Missouri     8   25.0
# 1584                       Symptoms of Anxiety Disorder  Missouri     8   28.3
# 1654  Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     8   32.9
# 1724                    Symptoms of Depressive Disorder  Missouri     9   25.6
# 1794                       Symptoms of Anxiety Disorder  Missouri     9   32.2
# 1864  Symptoms of Anxiety Disorder or Depressive Dis...  Missouri     9   35.8
# 1934                    Symptoms of Depressive Disorder  Missouri    10   28.8

# %%
#mo_df.dtypes
Mo_df["week"]
mo_wks= Mo_df.groupby("indicator")["week"].count()
mo_wks
# Out:
# indicator
# Symptoms of Anxiety Disorder                            9
# Symptoms of Anxiety Disorder or Depressive Disorder     9
# Symptoms of Depressive Disorder                        10
# Name: week, dtype: int64

# %%
#chart for Mo %'s' after ten weeks
mo_wks= Mo_df.groupby("indicator")["value"].mean()

Mo_df.groupby("indicator")["value"].mean()
mo_wks = Mo_df.groupby("indicator")["value"].mean()
mo_wks

mo_wks.plot(kind="barh",width = (.45),figsize=(10, 5), color=["cornflowerblue","powderblue","steelblue"],
            edgeColor=('black'), linestyle='-')

# %%
all_states=file_one.loc[(file_one['state']=='United States')]
all_states

cleaned_all_states=all_states[['indicator','state','week', 'value']].copy()
cleaned_all_states
# Out:
#                             indicator          state  week  value
# 0     Symptoms of Depressive Disorder  United States     1   23.5
# 1     Symptoms of Depressive Disorder  United States     1   32.7
# 2     Symptoms of Depressive Disorder  United States     1   25.7
# 3     Symptoms of Depressive Disorder  United States     1   24.8
# 4     Symptoms of Depressive Disorder  United States     1   23.2
# ...                               ...            ...   ...    ...
# 1974     Symptoms of Anxiety Disorder  United States    10   43.3
# 1975     Symptoms of Anxiety Disorder  United States    10   40.7
# 1976     Symptoms of Anxiety Disorder  United States    10   34.9
# 1977     Symptoms of Anxiety Disorder  United States    10   37.0
# 1978     Symptoms of Anxiety Disorder  United States    10   28.3
#
# [551 rows x 4 columns]

# %%
cleanedAll=cleaned_all_states.groupby(['week','indicator'])
cleanedAll.count().head(10)

country_mean=cleanedAll['value'].mean()
final_total=pd.DataFrame({'National Average(%)':country_mean})
final_total.head()
# Out:
#                                                          National Average(%)
# week indicator
# 1    Symptoms of Anxiety Disorder                                  30.468421
#      Symptoms of Anxiety Disorder or Depressive Diso...            35.921053
#      Symptoms of Depressive Disorder                               23.831579
# 2    Symptoms of Anxiety Disorder                                  29.789474
#      Symptoms of Anxiety Disorder or Depressive Diso...            34.326316

# %%
#chart for national average%
final_total= cleaned_all_states.groupby("indicator")["value"].mean()

cleaned_all_states.groupby("indicator")["value"].mean()
final_total = Mo_df.groupby("indicator")["value"].mean()
final_total

final_total.plot(kind="barh",width = (.45),figsize=(10, 5), color=["royalblue","navy","lightblue"],
            edgeColor=('black'), linestyle='-')
